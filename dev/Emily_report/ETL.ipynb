# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime

# %%
votes = "Resources/votes.csv"
pd_votes = pd.read_csv(votes)

# %%
pd_votes.head()
# Out:
#    Unnamed: 0   X  combined_fips  votes_dem_2016  votes_gop_2016  \
# 0          30  29           1001            5908           18110
# 1          31  30           1003           18409           72780
# 2          32  31           1005            4848            5431
# 3          33  32           1007            1874            6733
# 4          34  33           1009            2150           22808
#
#    total_votes_2016   Clinton     Trump  diff_2016  per_point_diff_2016  ...  \
# 0             24661  0.239569  0.734358      12202            -0.494789  ...
# 1             94090  0.195653  0.773515      54371            -0.577862  ...
# 2             10390  0.466603  0.522714        583            -0.056112  ...
# 3              8748  0.214220  0.769662       4859            -0.555441  ...
# 4             25384  0.084699  0.898519      20658            -0.813820  ...
#
#   AFN120207 BPS030214  LND110210  Density  Clinton_Obama  Trump_Romney  \
# ...

# %%
election_one = "Resources/2008_US_Election.csv"
election_two = "Resources/primary_results.csv"


pd_election_one = pd.read_csv(election_one)
pd_election_two = pd.read_csv(election_two)

# %%
pd_election_one.head()
# Out:
#    year   state  state_po  state_fips  state_fips.1  state_fips.2  \
# 0  2008  Alabama       AL           1            63            41
# 1  2008  Alabama       AL           1            63            41
# 2  2008  Alabama       AL           1            63            41
# 3  2008  Alabama       AL           1            63            41
# 4  2008   Alaska       AK           2            94            81
#
#    state_fips.3      state_fips.4 state_fips.5  state_fips.6  state_fips.7  \
# 0  US President      McCain, John   republican         False       1266546
# 1  US President  Obama, Barack H.     democrat         False        813479
# 2  US President               NaN  independent         False         16089
# 3  US President               NaN          NaN          True          3705
# 4  US President      McCain, John   republican         False        193841
#
#    state_fips.8  state_fips.9  state_fips.10
# 0       2099819      20171015            NaN
# ...

# %%
pd_election_two.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
#count demo & republicans
pd_election_two.groupby(["state","party"]).count()
# Out:
#                           state_abbreviation  county  fips  candidate  votes  \
# state         party
# Alabama       Democrat                   134     134   134        134    134
#               Republican                 335     335   335        335    335
# Alaska        Democrat                    80      80    80         80     80
#               Republican                 200     200   200        200    200
# Arizona       Democrat                    30      30    30         30     30
# ...                                      ...     ...   ...        ...    ...
# West Virginia Republican                 165     165   165        165    165
# Wisconsin     Democrat                   144     144   144        144    144
#               Republican                 216     216   216        216    216
# Wyoming       Democrat                    46      46    46         46     46
#               Republican                  48      48    48         48     48
#
# ...

# %%
pd_election_one.groupby(["state ","state_fips.7","state_fips.8"]).count()
# Out:
#                                    year  state_po  state_fips  state_fips.1  \
# state   state_fips.7 state_fips.8
# Alabama 3705         2099819          1         1           1             1
#         16089        2099819          1         1           1             1
#         813479       2099819          1         1           1             1
#         1266546      2099819          1         1           1             1
# Alaska  1589         326197           1         1           1             1
# ...                                 ...       ...         ...           ...
# Wyoming 1521         254904           1         1           1             1
#         1594         254904           1         1           1             1
#         3717         254904           1         1           1             1
#         82868        254904           1         1           1             1
#         164958       254904           1         1           1             1
#
# ...

# %%
pd_election_one.groupby(["state "]).count()
# Out:
#                       year  state_po  state_fips  state_fips.1  state_fips.2  \
# state
# Alabama                  4         4           4             4             4
# Alaska                   6         6           6             6             6
# Arizona                  6         6           6             6             6
# Arkansas                 7         7           7             7             7
# California               7         7           7             7             7
# Colorado                16        16          16            16            16
# Connecticut              4         4           4             4             4
# Delaware                 7         7           7             7             7
# District of Columbia     5         5           5             5             5
# Florida                 14        14          14            14            14
# Georgia                  5         5           5             5             5
# ...

# %%
#create a DataFrame from csv
my_dataframe = pd.read_csv('Resources/2008_US_Election.csv')
#drop any empty cells
my_dataframe.dropna(axis =0, how ='any',thresh = None, subset = None, inplace = False)
# Out:
# Empty DataFrame
# Columns: [year, state , state_po, state_fips, state_fips.1, state_fips.2, state_fips.3, state_fips.4, state_fips.5, state_fips.6, state_fips.7, state_fips.8, state_fips.9, state_fips.10]
# Index: []

# %%
pd_election_one.head(15)
# Out:
#     year   state  state_po  state_fips  state_fips.1  state_fips.2  \
# 0   2008  Alabama       AL           1            63            41
# 1   2008  Alabama       AL           1            63            41
# 2   2008  Alabama       AL           1            63            41
# 3   2008  Alabama       AL           1            63            41
# 4   2008   Alaska       AK           2            94            81
# 5   2008   Alaska       AK           2            94            81
# 6   2008   Alaska       AK           2            94            81
# 7   2008   Alaska       AK           2            94            81
# 8   2008   Alaska       AK           2            94            81
# 9   2008   Alaska       AK           2            94            81
# 10  2008  Arizona       AZ           4            86            61
# 11  2008  Arizona       AZ           4            86            61
# 12  2008  Arizona       AZ           4            86            61
# ...

# %%
df_election_one = pd.read_csv(election_one)
df_election_one.reset_index(inplace = True)
df_election_one = df_election_one.rename(columns = {'state_fips.7':'candidatevotes',
                                                    'state_fips.8':'totalvotes'})

# %%
df_election_one.head()
# Out:
#    index  year   state  state_po  state_fips  state_fips.1  state_fips.2  \
# 0      0  2008  Alabama       AL           1            63            41
# 1      1  2008  Alabama       AL           1            63            41
# 2      2  2008  Alabama       AL           1            63            41
# 3      3  2008  Alabama       AL           1            63            41
# 4      4  2008   Alaska       AK           2            94            81
#
#    state_fips.3      state_fips.4 state_fips.5  state_fips.6  candidatevotes  \
# 0  US President      McCain, John   republican         False         1266546
# 1  US President  Obama, Barack H.     democrat         False          813479
# 2  US President               NaN  independent         False           16089
# 3  US President               NaN          NaN          True            3705
# 4  US President      McCain, John   republican         False          193841
#
#    totalvotes  state_fips.9  state_fips.10
# ...

# %%
pd_votes.groupby(["total_votes_2016","state_abbr"]).count()
# Out:
#                              Unnamed: 0  X  combined_fips  votes_dem_2016  \
# total_votes_2016 state_abbr
# 64               TX                   1  1              1               1
# 159              TX                   1  1              1               1
# 186              TX                   1  1              1               1
# 263              NE                   1  1              1               1
# 283              ID                   1  1              1               1
# ...                                 ... ..            ...             ...
# 1092116          CA                   1  1              1               1
# 1201934          AZ                   1  1              1               1
# 1302887          TX                   1  1              1               1
# 2055215          IL                   1  1              1               1
# 2652072          CA                   1  1              1               1
#
# ...

# %%
vote_stratified_votes = pd_votes.groupby(["state_abbr"]).count() 
vote_stratified_votes
# Out:
#             Unnamed: 0    X  combined_fips  votes_dem_2016  votes_gop_2016  \
# state_abbr
# AL                  67   67             67              67              67
# AR                  75   75             75              75              75
# AZ                  15   15             15              15              15
# CA                  58   58             58              58              58
# CO                  64   64             64              64              64
# CT                   8    8              8               8               8
# DC                   1    1              1               1               1
# DE                   3    3              3               3               3
# FL                  67   67             67              67              67
# GA                 159  159            159             159             159
# HI                   4    4              4               4               4
# ...

# %%
total_votes_2016 = pd_votes["total_votes_2016"]
total_votes_2012 = pd_votes["total_votes_2012"]
state_abbr = pd_votes["state_abbr"]

# %%
total_votes = pd.DataFrame({"state_abbr":state_abbr,
                            "total_votes_2016":total_votes_2016,
                            "total_votes_2012":total_votes_2012})
total_votes
# Out:
#      state_abbr  total_votes_2016  total_votes_2012
# 0            AL             24661             23909
# 1            AL             94090             84988
# 2            AL             10390             11459
# 3            AL              8748              8391
# 4            AL             25384             23980
# ...         ...               ...               ...
# 3107         WY             16661             16750
# 3108         WY             12176             11356
# 3109         WY              8053              8453
# 3110         WY              3715              3911
# 3111         WY              3334              3323
#
# [3112 rows x 3 columns]

# %%
 total_votes.groupby(["state_abbr"]).sum()
# Out:
#             total_votes_2016  total_votes_2012
# state_abbr
# AL                   2078165           2064699
# AR                   1108615           1062831
# AZ                   2062810           2041519
# CA                  11733523          10538656
# CO                   2564185           2419698
# CT                   1623542           1562187
# DC                    280272            243348
# DE                    441535            413844
# FL                   9386750           8470205
# GA                   4029564           3877038
# HI                    428825            429494
# IA                   1542880           1565968
# ID                    688235            651871
# IL                   5374280           5113726
# IN                   2722029           2602883
# KS                   1147143           1131244
# KY                   1922218           1796736
# LA                   2027731           1993555
# MA                   3231531           3129731
# ...

# %%
connection_string = "postgres:postgres@localhost:52589/votes_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
total_votes.to_sql(name='total_votes', con=engine, if_exists='append', index=False)
