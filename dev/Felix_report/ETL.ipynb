# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import datetime

# Study data files
election_metadata = "MITResults.csv"
state_votes_metadata = "votes_by_state.csv"

# Read the data and the study results
election_metadata = pd.read_csv(election_metadata)
state_votes_metadata = pd.read_csv(state_votes_metadata)

# %%
election_metadata.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                      candidate                       party  writein  \
# 0                Carter, Jimmy                    democrat    False
# 1                 Ford, Gerald                  republican    False
# 2               Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin \\"Ben\"\""                 prohibition    False
# 4                    Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
state_votes_metadata.head()
# Out:
#   Unnamed: 0  Election_Year Unnamed: 2 State Unnamed: 4 Unnamed: 5  \
# 0          (           2012          "    AL          "          "
# 1          (           2012          "    AL          "          "
# 2          (           2012          "    AR          "          "
# 3          (           2012          "    AR          "          "
# 4          (           2012          "    AZ          "          "
#
#   Candidate_Name Unnamed: 7 Unnamed: 8 Party_Affiliation Unnamed: 10    Votes  \
# 0  Obama, Barack          "          "          democrat           "   793620
# 1   Romney, Mitt          "          "        republican           "  1252453
# 2  Obama, Barack          "          "          democrat           "   391953
# 3   Romney, Mitt          "          "        republican           "   643717
# 4  Obama, Barack          "          "          democrat           "   900081
#
#   Unnamed: 12                                        SQL_Insert
# ...

# %%
#count demo & republicans
election_metadata.groupby(["totalvotes","candidatevotes"]).count()
# Out:
#                            year  state  state_po  state_fips  state_cen  \
# totalvotes candidatevotes
# 123574     1176               1      1         1           1          1
#            6785               1      1         1           1          1
#            44058              1      1         1           1          1
#            71555              1      1         1           1          1
# 156343     1387               1      1         1           1          1
# ...                         ...    ...       ...         ...        ...
# 14181595   120739             1      1         1           1          1
#            278657             1      1         1           1          1
#            478500             1      1         1           1          1
#            4483810            1      1         1           1          1
#            8753788            1      1         1           1          1
#
#                            state_ic  office  candidate  party  writein  \
# ...

# %%
#state_votes_metadata = pd.read_csv(state_votes_metadata)
state_votes_metadata.reset_index(inplace = True)
state_votes_metadata = state_votes_metadata.rename(columns = {'office':'office they are running for',
                                                    'candidate':'name of candidate'})

# %%
state_votes_metadata
# Out:
#      index Unnamed: 0  Election_Year Unnamed: 2 State Unnamed: 4 Unnamed: 5  \
# 0        0          (           2012          "    AL          "          "
# 1        1          (           2012          "    AL          "          "
# 2        2          (           2012          "    AR          "          "
# 3        3          (           2012          "    AR          "          "
# 4        4          (           2012          "    AZ          "          "
# ..     ...        ...            ...        ...   ...        ...        ...
# 195    195          (           2016          "    WI          "          "
# 196    196          (           2016          "    WV          "          "
# 197    197          (           2016          "    WV          "          "
# 198    198          (           2016          "    WY          "          "
# 199    199          (           2016          "    WY          "          "
#
# ...

# %%
engine = create_engine(f'sqlite://{state_votes_metadata}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e4f8f4e2a8af> in <module>
# ----> 1 engine = create_engine(f'sqlite://{state_votes_metadata}')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      52     def create(self, name_or_url, **kwargs):
#      53         # create url.URL object
# ---> 54         u = url.make_url(name_or_url)
#      55
#      56         plugins = u._instantiate_plugins(kwargs)
#
# ...
